# %%
import xarray as xr
import numpy as np

# %%
fold = 1
original = xr.open_dataset(f'/opt/aqmsp_models/models/config_s2p10/anp/cpcb_ijcai24_dec23/config1/fold_{fold}/predictions.nc')
d9 = xr.open_dataset(f'/tmp/p0.9/config1/fold_{fold}/predictions.nc')
d7 = xr.open_dataset(f'/tmp/p0.7/config1/fold_{fold}/predictions.nc')
d5 = xr.open_dataset(f'/tmp/p0.5/config1/fold_{fold}/predictions.nc')

# %%
np.abs((original["PM2.5_pred"] - d9["PM2.5_pred"])).sum()/original["PM2.5_pred"].sum()*100
# Out:
# <xarray.DataArray 'PM2.5_pred' ()>
# array(2.49944311)

# %%
np.abs(original["PM2.5_pred"] - d7["PM2.5_pred"]).sum()/original["PM2.5_pred"].sum()*100
# Out:
# <xarray.DataArray 'PM2.5_pred' ()>
# array(6.44910634)

# %%
np.abs(original["PM2.5_pred"] - d5["PM2.5_pred"]).sum()/original["PM2.5_pred"].sum()*100
# Out:
# <xarray.DataArray 'PM2.5_pred' ()>
# array(10.00468135)
